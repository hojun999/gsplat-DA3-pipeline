# %% [markdown]
# # Experiment DA3 gsplat
#
# Reserved for experiment work. The main execution path is `01_main_splatfacto_pipeline.ipynb`.
